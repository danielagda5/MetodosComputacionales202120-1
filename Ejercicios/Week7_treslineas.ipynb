# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib          import rc 
from matplotlib          import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(0,10,30)

y = np.zeros((3,len(x)))

y[0] = 2*x-2
y[1] = -0.5*x + 0.5
y[2] = 4 - x

# %%
A = np.array([[2,-1],[1,2],[1,1]])
b = np.array([2,1,4])
At = A.T
print(A.shape)
print(b.shape)
# Out:
# (3, 2)
# (3,)

# %%
M = np.dot(At,A)
print(M)
# Out:
# [[6 1]
#  [1 6]]

# %%
bt = np.dot(At,b)

# %%
xsol = np.linalg.solve(M,bt)

# %%
print(xsol)
# Out:
# [1.42857143 0.42857143]

# %%
for l in range(y.shape[0]):
    plt.plot(x,y[l])
plt.scatter(xsol[0],xsol[1],color='r')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
# Esta sería la menor distancia
np.linalg.norm(np.dot(A,xsol)-b)
# Out:
# 2.5354627641855494

# %%
x1 = np.arange(-5.,5.,0.03)
y1 = np.arange(-5.,5.,0.03)
X,Y = np.meshgrid(x1,y1)

d = np.zeros((len(x1),len(y1)))


for i in range(len(x1)):
    for j in range(len(y1)):
        d[i,j] =  np.linalg.norm(np.dot(A,np.array([x1[i],y1[j]]))-b)

# %%
ii = np.where( d == np.amin(d) )
print(ii)
# Out:
# (array([214]), array([181]))

# %%
print(x1[ii[0]],y1[ii[1]])
# Out:
# [1.42] [0.43]

# %%
fig1 = plt.figure()
ax = fig1.add_subplot(1,1,1, projection = '3d',elev = 36, azim = 50)
ax.plot_surface(X, Y,d,cmap=cm.coolwarm)
ax.set_xlabel(r'$x$', fontsize=10)
ax.set_ylabel(r'$y$', fontsize=10)
ax.set_zlabel(r'$d(x^{*})$', fontsize=10)
#plt.savefig('Rectas.pdf')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# Text(0.5, 0, '$d(x^{*})$')
